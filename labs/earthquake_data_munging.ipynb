# %% [markdown]
# <a href="https://colab.research.google.com/github/elhamkashi/DSPS_EKashi/blob/main/labs/earthquake_data_munging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
earthquakes=pd.read_csv("https://raw.githubusercontent.com/fedhere/DSPS_FBianco/refs/heads/main/data/earthquakes.csv", sep="\s+ ")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-2977703692.py:1: SyntaxWarning: invalid escape sequence '\s'
#   earthquakes=pd.read_csv("https://raw.githubusercontent.com/fedhere/DSPS_FBianco/refs/heads/main/data/earthquakes.csv", sep="\s+ ")
# /tmp/ipython-input-2977703692.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   earthquakes=pd.read_csv("https://raw.githubusercontent.com/fedhere/DSPS_FBianco/refs/heads/main/data/earthquakes.csv", sep="\s+ ")

# %%
earthquakes=pd.read_csv("https://raw.githubusercontent.com/fedhere/DSPS_FBianco/refs/heads/main/data/earthquakes.csv", sep=" ")

# %%
earthquakes.shape # raws, columns
# Out:
# (70798, 34)

# %%
earthquakes.head() # must have ()
# Out:
#    #YYY/MM/DD  HH:mm:SS.ss  ET  GT MAG  Unnamed: 5  M  Unnamed: 7  Unnamed: 8  \
# 0  1984/01/01  01:30:57.52  eq NaN   l        2.02  c         NaN         NaN
# 1  1984/01/01  05:31:34.16  eq NaN   l        2.12  c         NaN         NaN
# 2  1984/01/01  06:59:05.14  eq NaN   l        2.43  c         NaN         NaN
# 3  1984/01/01  11:10:25.29  eq NaN   l        2.07  c         NaN         NaN
# 4  1984/01/01  19:38:19.79  eq NaN   l        2.13  c         NaN         NaN
#
#    Unnamed: 9  ...     Q  Unnamed: 25  EVID Unnamed: 27 Unnamed: 28  \
# 0      33.246  ...  17.0          NaN   NaN         NaN         NaN
# 1      32.945  ...  42.0          NaN   NaN         NaN         NaN
# 2      33.343  ...  30.0          NaN   NaN         NaN         NaN
# 3      33.668  ...   NaN          NaN   NaN         NaN         NaN
# 4      33.963  ...  49.0          NaN   NaN         NaN         NaN
#
#    Unnamed: 29  Unnamed: 30  Unnamed: 31  NPH  NGRM
# 0          NaN          NaN          NaN  NaN   NaN
# 1          NaN          NaN          NaN  NaN   NaN
# 2          NaN          NaN          NaN  NaN   NaN
# 3          NaN          NaN          NaN  NaN   NaN
# 4          NaN          NaN          NaN  NaN   NaN
#
# [5 rows x 34 columns]

# %%
earthquakes.tail()
# Out:
#        #YYY/MM/DD  HH:mm:SS.ss  ET  GT MAG  Unnamed: 5  M  Unnamed: 7  \
# 70793  2002/12/29  19:37:24.56  eq NaN   l        2.21  l         NaN
# 70794  2002/12/29  20:17:33.40  eq NaN   l        2.02  l         NaN
# 70795  2002/12/29  20:21:28.73  eq NaN   l        2.07  l         NaN
# 70796  2002/12/30  21:51:52.55  eq NaN   l        2.31  l         NaN
# 70797  2002/12/30  23:38:49.79  eq NaN   l        2.05  l         NaN
#
#        Unnamed: 8  Unnamed: 9  ...   Q  Unnamed: 25  EVID Unnamed: 27  \
# 70793         NaN    35.31400  ... NaN          NaN   NaN         NaN
# 70794         NaN    35.32133  ... NaN          NaN   NaN         NaN
# 70795         NaN    35.32150  ... NaN          NaN   NaN         NaN
# 70796         NaN    35.31867  ... NaN          NaN   NaN         NaN
# 70797         NaN    35.31450  ... NaN          NaN   NaN         NaN
#
#       Unnamed: 28  Unnamed: 29  Unnamed: 30  Unnamed: 31  NPH  NGRM
# 70793         NaN          NaN          NaN          NaN  NaN   NaN
# 70794         NaN          NaN          NaN          NaN  NaN   NaN
# 70795         NaN          NaN          NaN          NaN  NaN   NaN
# 70796         NaN          NaN          NaN          NaN  NaN   NaN
# 70797         NaN          NaN          NaN          NaN  NaN   NaN
#
# [5 rows x 34 columns]

# %%
earthquakes.

# %%
earthquakes.columns
# Out:
# Index(['#YYY/MM/DD', 'HH:mm:SS.ss', 'ET', 'GT', 'MAG', 'Unnamed: 5', 'M',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'LAT', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'LON', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'DEPTH', 'Q', 'Unnamed: 25', 'EVID',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'NPH', 'NGRM'],
#       dtype='object')

# %%
earthquakes[['#YYY/MM/DD', 'HH:mm:SS.ss', 'ET', 'GT', 'MAG']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-520990174.py in <cell line: 0>()
# ----> 1 earthquakes[['#YYY/MM/DD', 'HH:mm:SS.ss', 'ET', 'GT', 'MAG']]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6247         if nmissing:
#    6248             if nmissing == len(indexer):
# -> 6249                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['#YYY/MM/DD', 'HH:mm:SS.ss', 'ET', 'GT', 'MAG'], dtype='object')] are in the [columns]"

# %%
earthquakes.dtypes
# Out:
# #YYY/MM/DD HH:mm:SS.ss ET GT MAG     object
# M                                    object
# LAT                                  object
# LON                                  object
# DEPTH Q                              object
# EVID                                 object
# NPH NGRM                            float64
# dtype: object

# %%
earthquakes.rename({"#YYY/MM/DD": "date", "HH:mm:SS.ss": "time",  "MAG": "mag"}, axis=1)   #with , inplace=True it doesnot show the results
# Out:
#       #YYY/MM/DD HH:mm:SS.ss ET GT MAG         M                  LAT     LON  \
# 0            1984/01/01 01:30:57.52 eq  l 2.02 c  33.24600 -116.43300   1.6 C
# 1            1984/01/01 05:31:34.16 eq  l 2.12 c  32.94500 -116.29500   5.4 C
# 2            1984/01/01 06:59:05.14 eq  l 2.43 c  33.34300 -117.62800   5.6 C
# 3            1984/01/01 11:10:25.29 eq  l 2.07 c  33.66800 -116.78000  13.8 C
# 4            1984/01/01 19:38:19.79 eq  l 2.13 c  33.96300 -116.29000   2.7 C
# ...                                ...       ...                  ...     ...
# 70793        2002/12/29 19:37:24.56 eq  l 2.21 l  35.31400 -118.66767   3.7 A
# 70794        2002/12/29 20:17:33.40 eq  l 2.02 l  35.32133 -118.66000   1.8 A
# 70795        2002/12/29 20:21:28.73 eq  l 2.07 l  35.32150 -118.66617   1.9 A
# 70796        2002/12/30 21:51:52.55 eq  l 2.31 l  35.31867 -118.66250   1.5 A
# 70797        2002/12/30 23:38:49.79 eq  l 2.05 l  35.31450 -118.66333   1.9 A
#
#        DEPTH Q EVID  NPH NGRM
# 0        28255   13      17.0
# 1        28259   18      42.0
# 2        28260   13      30.0
# 3        28270   19      40.0
# 4        28553   40      49.0
# ...        ...  ...       ...
# 70793  9874709   25     948.0
# 70794  9874745   48     245.0
# 70795  9874749   53     277.0
# 70796  9875017   66     404.0
# 70797  9875061   54     283.0
#
# [70798 rows x 7 columns]

# %%
earthquakes
# Out:
#       #YYY/MM/DD HH:mm:SS.ss ET GT MAG         M                  LAT     LON  \
# 0            1984/01/01 01:30:57.52 eq  l 2.02 c  33.24600 -116.43300   1.6 C
# 1            1984/01/01 05:31:34.16 eq  l 2.12 c  32.94500 -116.29500   5.4 C
# 2            1984/01/01 06:59:05.14 eq  l 2.43 c  33.34300 -117.62800   5.6 C
# 3            1984/01/01 11:10:25.29 eq  l 2.07 c  33.66800 -116.78000  13.8 C
# 4            1984/01/01 19:38:19.79 eq  l 2.13 c  33.96300 -116.29000   2.7 C
# ...                                ...       ...                  ...     ...
# 70793        2002/12/29 19:37:24.56 eq  l 2.21 l  35.31400 -118.66767   3.7 A
# 70794        2002/12/29 20:17:33.40 eq  l 2.02 l  35.32133 -118.66000   1.8 A
# 70795        2002/12/29 20:21:28.73 eq  l 2.07 l  35.32150 -118.66617   1.9 A
# 70796        2002/12/30 21:51:52.55 eq  l 2.31 l  35.31867 -118.66250   1.5 A
# 70797        2002/12/30 23:38:49.79 eq  l 2.05 l  35.31450 -118.66333   1.9 A
#
#        DEPTH Q EVID  NPH NGRM
# 0        28255   13      17.0
# 1        28259   18      42.0
# 2        28260   13      30.0
# 3        28270   19      40.0
# 4        28553   40      49.0
# ...        ...  ...       ...
# 70793  9874709   25     948.0
# 70794  9874745   48     245.0
# 70795  9874749   53     277.0
# 70796  9875017   66     404.0
# 70797  9875061   54     283.0
#
# [70798 rows x 7 columns]

# %%
earthquakes.describe()
# Out:
#            NPH NGRM
# count  68275.000000
# mean     153.359546
# std      144.226954
# min        0.000000
# 25%       57.000000
# 50%      107.000000
# 75%      199.000000
# max      999.000000

# %%
pd.to_datetime("2002/12/29" + " " +"19:37:24.56")
# Out:
# Timestamp('2002-12-29 19:37:24.560000')

# %%
earthquakes["dates"].map(pd.to_datetime)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dates'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4043025609.py in <cell line: 0>()
# ----> 1 earthquakes["dates"].map(pd.to_datetime)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'dates'

# %%
#[0,1]
 mydictionary={"v1":0, "v2":1}
# Out:
#   File "/tmp/ipython-input-801711891.py", line 2
#     mydictionary={"v1":0, "v2":1}
#     ^
# IndentationError: unexpected indent

# %%
mydictionary["v1"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-101192410.py in <cell line: 0>()
# ----> 1 mydictionary["v1"]
#
# NameError: name 'mydictionary' is not defined

# %%
earthquakes.rename({}) #{} shows a dictionary
